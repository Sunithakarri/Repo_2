# %%
import pandas as pd

# %%
df = pd.read_csv('student_marks.csv')

# %%
df
# Out:
#     Student_ID  Test_1  Test_2  Test_3  Test_4  Test_5  Test_6  Test_7  \
# 0        22000      78      87      91      91      88      98      94
# 1        22001      79      71      81      72      73      68      59
# 2        22002      66      65      70      74      78      86      87
# 3        22003      60      58      54      61      54      57      64
# 4        22004      99      95      96      93      97      89      92
# 5        22005      41      36      35      28      35      36      27
# 6        22006      47      50      47      57      62      64      71
# 7        22007      84      74      70      68      58      59      56
# 8        22008      74      64      58      57      53      51      47
# 9        22009      87      81      73      74      71      63      53
# 10       22010      40      34      37      33      31      35      39
# 11       22011      91      84      78      74      76      80      80
# ...

# %%
df = df[df["Test_3"].notna()]

# %%
df
# Out:
#     Student_ID  Test_1  Test_2  Test_3  Test_4  Test_5  Test_6  Test_7  \
# 0        22000      78      87      91      91      88      98      94
# 1        22001      79      71      81      72      73      68      59
# 2        22002      66      65      70      74      78      86      87
# 3        22003      60      58      54      61      54      57      64
# 4        22004      99      95      96      93      97      89      92
# 5        22005      41      36      35      28      35      36      27
# 6        22006      47      50      47      57      62      64      71
# 7        22007      84      74      70      68      58      59      56
# 8        22008      74      64      58      57      53      51      47
# 9        22009      87      81      73      74      71      63      53
# 10       22010      40      34      37      33      31      35      39
# 11       22011      91      84      78      74      76      80      80
# ...

# %%
df["Test_3"].notna()
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# 10    True
# 11    True
# 12    True
# 13    True
# 14    True
# 15    True
# 16    True
# 17    True
# 18    True
# 19    True
# 20    True
# 21    True
# 22    True
# 23    True
# 24    True
# 25    True
# 26    True
# 27    True
# 28    True
# 29    True
# 30    True
# 31    True
# 32    True
# 33    True
# 34    True
# 35    True
# 36    True
# 37    True
# 38    True
# 39    True
# 40    True
# 41    True
# 42    True
# 43    True
# 44    True
# 45    True
# 46    True
# 47    True
# 48    True
# 49    True
# 50    True
# 51    True
# 52    True
# 53    True
# 54    True
# 55    True
# Name: Test_3, dtype: bool

# %%
df["Test_3"].isna()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# 50    False
# 51    False
# 52    False
# 53    False
# 54    False
# 55    False
# Name: Test_3, dtype: bool

# %%
df
# Out:
#     Student_ID  Test_1  Test_2  Test_3  Test_4  Test_5  Test_6  Test_7  \
# 0        22000      78      87      91      91      88      98      94
# 1        22001      79      71      81      72      73      68      59
# 2        22002      66      65      70      74      78      86      87
# 3        22003      60      58      54      61      54      57      64
# 4        22004      99      95      96      93      97      89      92
# 5        22005      41      36      35      28      35      36      27
# 6        22006      47      50      47      57      62      64      71
# 7        22007      84      74      70      68      58      59      56
# 8        22008      74      64      58      57      53      51      47
# 9        22009      87      81      73      74      71      63      53
# 10       22010      40      34      37      33      31      35      39
# 11       22011      91      84      78      74      76      80      80
# ...

# %%
df["avg of test_1 and test_2"] = df["Test_1"] + df["Test_2"]

# %%
df
# Out:
#     Student_ID  Test_1  Test_2  Test_3  Test_4  Test_5  Test_6  Test_7  \
# 0        22000      78      87      91      91      88      98      94
# 1        22001      79      71      81      72      73      68      59
# 2        22002      66      65      70      74      78      86      87
# 3        22003      60      58      54      61      54      57      64
# 4        22004      99      95      96      93      97      89      92
# 5        22005      41      36      35      28      35      36      27
# 6        22006      47      50      47      57      62      64      71
# 7        22007      84      74      70      68      58      59      56
# 8        22008      74      64      58      57      53      51      47
# 9        22009      87      81      73      74      71      63      53
# 10       22010      40      34      37      33      31      35      39
# 11       22011      91      84      78      74      76      80      80
# ...

# %%
df["id_test1"] = df["Student_ID"].astype(str) +  " :"  + df["Test_1"].astype(str)
df
# Out:
#     Student_ID  Test_1  Test_2  Test_3  Test_4  Test_5  Test_6  Test_7  \
# 0        22000      78      87      91      91      88      98      94
# 1        22001      79      71      81      72      73      68      59
# 2        22002      66      65      70      74      78      86      87
# 3        22003      60      58      54      61      54      57      64
# 4        22004      99      95      96      93      97      89      92
# 5        22005      41      36      35      28      35      36      27
# 6        22006      47      50      47      57      62      64      71
# 7        22007      84      74      70      68      58      59      56
# 8        22008      74      64      58      57      53      51      47
# 9        22009      87      81      73      74      71      63      53
# 10       22010      40      34      37      33      31      35      39
# 11       22011      91      84      78      74      76      80      80
# ...

# %%
df.reset_index()
# Out:
#     index  Student_ID  Test_1  Test_2  Test_3  Test_4  Test_5  Test_6  Test_7  \
# 0       0       22000      78      87      91      91      88      98      94
# 1       1       22001      79      71      81      72      73      68      59
# 2       2       22002      66      65      70      74      78      86      87
# 3       3       22003      60      58      54      61      54      57      64
# 4       4       22004      99      95      96      93      97      89      92
# 5       5       22005      41      36      35      28      35      36      27
# 6       6       22006      47      50      47      57      62      64      71
# 7       7       22007      84      74      70      68      58      59      56
# 8       8       22008      74      64      58      57      53      51      47
# 9       9       22009      87      81      73      74      71      63      53
# 10     10       22010      40      34      37      33      31      35      39
# ...

# %%
df.iloc[3]
# Out:
# Student_ID                      22003
# Test_1                             60
# Test_2                             58
# Test_3                             54
# Test_4                             61
# Test_5                             54
# Test_6                             57
# Test_7                             64
# Test_8                             62
# Test_9                             72
# Test_10                            63
# Test_11                            72
# Test_12                            76
# avg of test_1 and test_2          118
# id_test1                    22003 :60
# Name: 3, dtype: object

# %%
df.iloc[51:]
# Out:
#     Student_ID  Test_1  Test_2  Test_3  Test_4  Test_5  Test_6  Test_7  \
# 51       22051      70      60      70      62      67      67      68
# 52       22052      63      73      70      63      60      67      61
# 53       22053      92     100     100     100     100     100      92
# 54       22054      64      55      54      61      63      57      47
# 55       22055      60      66      68      58      49      47      39
#
#     Test_8  Test_9  Test_10  Test_11  Test_12  avg of test_1 and test_2  \
# 51      67      72       69       64       65                       130
# 52      59      52       58       56       46                       136
# 53      87      94      100       94       98                       192
# 54      37      44       48       54       54                       119
# 55      29      39       44       39       45                       126
#
#      id_test1
# 51  22051 :70
# 52  22052 :63
# 53  22053 :92
# 54  22054 :64
# 55  22055 :60

# %%
df.value_counts()
# Out:
# Student_ID  Test_1  Test_2  Test_3  Test_4  Test_5  Test_6  Test_7  Test_8  Test_9  Test_10  Test_11  Test_12  avg of test_1 and test_2  id_test1
# 22000       78      87      91      91      88      98      94      100     100     100      100      93       165                       22000 :78     1
# 22001       79      71      81      72      73      68      59      69      59      60       61       67       150                       22001 :79     1
# 22030       54      54      48      38      35      45      46      47      41      37       30       25       108                       22030 :54     1
# 22031       84      93      97      89      86      95      100     100     100     99       100      100      177                       22031 :84     1
# 22032       95      100     94      100     98      99      100     90      80      84       75       80       195                       22032 :95     1
# ...

# %%
df["length"] = len(df["Test_1"])

# %%
df
# Out:
#     Student_ID  Test_1  Test_2  Test_3  Test_4  Test_5  Test_6  Test_7  \
# 0        22000      78      87      91      91      88      98      94
# 1        22001      79      71      81      72      73      68      59
# 2        22002      66      65      70      74      78      86      87
# 3        22003      60      58      54      61      54      57      64
# 4        22004      99      95      96      93      97      89      92
# 5        22005      41      36      35      28      35      36      27
# 6        22006      47      50      47      57      62      64      71
# 7        22007      84      74      70      68      58      59      56
# 8        22008      74      64      58      57      53      51      47
# 9        22009      87      81      73      74      71      63      53
# 10       22010      40      34      37      33      31      35      39
# 11       22011      91      84      78      74      76      80      80
# ...

# %%
df["length"] = df["Test_1"].astype(str).apply(len)
df
# Out:
#     Student_ID  Test_1  Test_2  Test_3  Test_4  Test_5  Test_6  Test_7  \
# 0        22000      78      87      91      91      88      98      94
# 1        22001      79      71      81      72      73      68      59
# 2        22002      66      65      70      74      78      86      87
# 3        22003      60      58      54      61      54      57      64
# 4        22004      99      95      96      93      97      89      92
# 5        22005      41      36      35      28      35      36      27
# 6        22006      47      50      47      57      62      64      71
# 7        22007      84      74      70      68      58      59      56
# 8        22008      74      64      58      57      53      51      47
# 9        22009      87      81      73      74      71      63      53
# 10       22010      40      34      37      33      31      35      39
# 11       22011      91      84      78      74      76      80      80
# ...

# %%
type(df["Test_3"].iloc[4])
# Out:
# numpy.int64
