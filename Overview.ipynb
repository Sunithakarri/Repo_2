# %%
import pandas as pd

# %%
df_1 = pd.read_csv("Test.csv")

# %%
df_1
# Out:
#                                                    text  label
# 0     I always wrote this series off as being a comp...      0
# 1     1st watched 12/7/2002 - 3 out of 10(Dir-Steve ...      0
# 2     This movie was so poorly written and directed ...      0
# 3     The most interesting thing about Miryang (Secr...      1
# 4     when i first read about "berlin am meer" i did...      0
# ...                                                 ...    ...
# 4995  This is the kind of picture John Lassiter woul...      1
# 4996  A MUST SEE! I saw WHIPPED at a press screening...      1
# 4997  NBC should be ashamed. I wouldn't allow my chi...      0
# 4998  This movie is a clumsy mishmash of various gho...      0
# 4999  Formula movie about the illegitimate son of a ...      0
#
# [5000 rows x 2 columns]

# %%
df_1.label.value_counts()
# Out:
# label
# 1    2505
# 0    2495
# Name: count, dtype: int64

# %%
type(df_1['text'])
# Out:
# pandas.core.series.Series

# %%
df_1[df_1['text'].isna()]
# Out:
# Empty DataFrame
# Columns: [text, label]
# Index: []

# %%
df_1[df_1['text'].notna()]
# Out:
#                                                    text  label
# 0     I always wrote this series off as being a comp...      0
# 1     1st watched 12/7/2002 - 3 out of 10(Dir-Steve ...      0
# 2     This movie was so poorly written and directed ...      0
# 3     The most interesting thing about Miryang (Secr...      1
# 4     when i first read about "berlin am meer" i did...      0
# ...                                                 ...    ...
# 4995  This is the kind of picture John Lassiter woul...      1
# 4996  A MUST SEE! I saw WHIPPED at a press screening...      1
# 4997  NBC should be ashamed. I wouldn't allow my chi...      0
# 4998  This movie is a clumsy mishmash of various gho...      0
# 4999  Formula movie about the illegitimate son of a ...      0
#
# [5000 rows x 2 columns]

# %%
df_1.rename(columns = {"text" : "Text" , "label" : "Label"},inplace =  True)

# %%
df_1
# Out:
#                                                    Text  Label
# 0     I always wrote this series off as being a comp...      0
# 1     1st watched 12/7/2002 - 3 out of 10(Dir-Steve ...      0
# 2     This movie was so poorly written and directed ...      0
# 3     The most interesting thing about Miryang (Secr...      1
# 4     when i first read about "berlin am meer" i did...      0
# ...                                                 ...    ...
# 4995  This is the kind of picture John Lassiter woul...      1
# 4996  A MUST SEE! I saw WHIPPED at a press screening...      1
# 4997  NBC should be ashamed. I wouldn't allow my chi...      0
# 4998  This movie is a clumsy mishmash of various gho...      0
# 4999  Formula movie about the illegitimate son of a ...      0
#
# [5000 rows x 2 columns]

# %%
df_1["Text_len"] = df_1["Text"].apply(len)

# %%
df_1
# Out:
#                                                    Text  Label  Text_len
# 0     I always wrote this series off as being a comp...      0      2105
# 1     1st watched 12/7/2002 - 3 out of 10(Dir-Steve ...      0      1070
# 2     This movie was so poorly written and directed ...      0      1402
# 3     The most interesting thing about Miryang (Secr...      1      4277
# 4     when i first read about "berlin am meer" i did...      0      1013
# ...                                                 ...    ...       ...
# 4995  This is the kind of picture John Lassiter woul...      1       594
# 4996  A MUST SEE! I saw WHIPPED at a press screening...      1       856
# 4997  NBC should be ashamed. I wouldn't allow my chi...      0       649
# 4998  This movie is a clumsy mishmash of various gho...      0       740
# 4999  Formula movie about the illegitimate son of a ...      0       637
#
# [5000 rows x 3 columns]

# %%
len(df_1['Label'])
# Out:
# 5000

# %%
df_1.iloc[0]
# Out:
# Text        I always wrote this series off as being a comp...
# Label                                                       0
# Text_len                                                 2105
# Name: 0, dtype: object

# %% [markdown]
# creating new column

# %%
df_1["Label_Text_len"] = df_1["Label"].astype(str) + " - " + df_1["Text_len"].astype(str)

# %%
df_1
# Out:
#                                                    Text  Label  Text_len  \
# 0     I always wrote this series off as being a comp...      0      2105
# 1     1st watched 12/7/2002 - 3 out of 10(Dir-Steve ...      0      1070
# 2     This movie was so poorly written and directed ...      0      1402
# 3     The most interesting thing about Miryang (Secr...      1      4277
# 4     when i first read about "berlin am meer" i did...      0      1013
# ...                                                 ...    ...       ...
# 4995  This is the kind of picture John Lassiter woul...      1       594
# 4996  A MUST SEE! I saw WHIPPED at a press screening...      1       856
# 4997  NBC should be ashamed. I wouldn't allow my chi...      0       649
# 4998  This movie is a clumsy mishmash of various gho...      0       740
# 4999  Formula movie about the illegitimate son of a ...      0       637
#
#      Label_Text_len
# 0          0 - 2105
# 1          0 - 1070
# 2          0 - 1402
# ...

# %%
df_1.iloc[:10]
# Out:
#                                                 Text  Label  Text_len  \
# 0  I always wrote this series off as being a comp...      0      2105
# 1  1st watched 12/7/2002 - 3 out of 10(Dir-Steve ...      0      1070
# 2  This movie was so poorly written and directed ...      0      1402
# 3  The most interesting thing about Miryang (Secr...      1      4277
# 4  when i first read about "berlin am meer" i did...      0      1013
# 5  I saw this film on September 1st, 2005 in Indi...      1      1887
# 6  I saw a screening of this movie last night. I ...      0      1470
# 7  William Hurt may not be an American matinee id...      1       955
# 8  IT IS A PIECE OF CRAP! not funny at all. durin...      0      1092
# 9  I'M BOUT IT(1997)<br /><br />Developed & publi...      0       893
#
#   Label_Text_len
# 0       0 - 2105
# 1       0 - 1070
# 2       0 - 1402
# 3       1 - 4277
# 4       0 - 1013
# 5       1 - 1887
# 6       0 - 1470
# 7        1 - 955
# 8       0 - 1092
# ...

# %%
df_1.iloc[4994:5000]
# Out:
#                                                    Text  Label  Text_len  \
# 4994  First, nobody can understand why this movie is...      1      1983
# 4995  This is the kind of picture John Lassiter woul...      1       594
# 4996  A MUST SEE! I saw WHIPPED at a press screening...      1       856
# 4997  NBC should be ashamed. I wouldn't allow my chi...      0       649
# 4998  This movie is a clumsy mishmash of various gho...      0       740
# 4999  Formula movie about the illegitimate son of a ...      0       637
#
#      Label_Text_len
# 4994       1 - 1983
# 4995        1 - 594
# 4996        1 - 856
# 4997        0 - 649
# 4998        0 - 740
# 4999        0 - 637

# %%
df_1.reset_index()
# Out:
#       index                                               Text  Label  \
# 0         0  I always wrote this series off as being a comp...      0
# 1         1  1st watched 12/7/2002 - 3 out of 10(Dir-Steve ...      0
# 2         2  This movie was so poorly written and directed ...      0
# 3         3  The most interesting thing about Miryang (Secr...      1
# 4         4  when i first read about "berlin am meer" i did...      0
# ...     ...                                                ...    ...
# 4995   4995  This is the kind of picture John Lassiter woul...      1
# 4996   4996  A MUST SEE! I saw WHIPPED at a press screening...      1
# 4997   4997  NBC should be ashamed. I wouldn't allow my chi...      0
# 4998   4998  This movie is a clumsy mishmash of various gho...      0
# 4999   4999  Formula movie about the illegitimate son of a ...      0
#
#       Text_len Label_Text_len
# 0         2105       0 - 2105
# 1         1070       0 - 1070
# 2         1402       0 - 1402
# ...

# %%
df_1.iloc[4994:5001]
# Out:
#                                                    Text  Label  Text_len  \
# 4994  First, nobody can understand why this movie is...      1      1983
# 4995  This is the kind of picture John Lassiter woul...      1       594
# 4996  A MUST SEE! I saw WHIPPED at a press screening...      1       856
# 4997  NBC should be ashamed. I wouldn't allow my chi...      0       649
# 4998  This movie is a clumsy mishmash of various gho...      0       740
# 4999  Formula movie about the illegitimate son of a ...      0       637
#
#      Label_Text_len
# 4994       1 - 1983
# 4995        1 - 594
# 4996        1 - 856
# 4997        0 - 649
# 4998        0 - 740
# 4999        0 - 637

# %%
df_1["Text"].iloc[500]
# Out:
# 'Elizabeth Taylor never could act at all and she was just her usual annoying, untalented self in this film. This was before she got so fat but she still looked very short and dumpy. Rock Hudson was OK as Bick Benedict but clearly an actor with more range like William Holden would have been better. James Dean certainly proved he knew how to mumble his way through a movie. The whole film is incredibly slow and goes on for far too long. The actors were all too young and lightweight and none of them aged convincingly due to the poor make-up. Hudson looked ridiculous just being padded out and Dean and Carroll Baker were obviously the same age.<br /><br />0/10.'

# %%
df_2 = pd.read_csv("Linkedin_scraped_ldjsons 2000.csv")
df_3 = pd.read_csv("Linkedin_scraped_ldjsons 2500.csv")

# %%
final_df = pd.concat([df_2,df_3])

# %%
final_df
# Out:
#                            _id  \
# 0     648065ab2aef3cb1519b437f
# 1     648065ab2aef3cb1519b4380
# 2     648065ab2aef3cb1519b4381
# 3     648065ab2aef3cb1519b4382
# 4     648065ab2aef3cb1519b4383
# ...                        ...
# 2494  648065ab2aef3cb1519b4dbb
# 2495  648065ab2aef3cb1519b4dbc
# 2496  648065ab2aef3cb1519b4dbd
# 2497  648065ab2aef3cb1519b4dbe
# 2498  648065ab2aef3cb1519b4dbf
#
#                                                   title  location  \
# 0     Internal Medicine Physician needed in Bossier ...       NaN
# 1                  Medical Oncology - Laurium, Michigan       NaN
# 2     Physician (MD/MO) - Pulmonology in Crown Point...       NaN
# 3           Physician (MD/MO) - Urology in Florence, KY       NaN
# 4     Locum Physician (MD/MO) - Anesthesiology in Mi...       NaN
# ...                                                 ...       ...
# 2494          Maternal-Fetal Med position in DuBois, PA       NaN
# ...

# %%
list(final_df["company"].unique())
# Out:
# ['CenterWell Senior Primary Care',
#  'Aspirus Health',
#  'The Inline Group',
#  'HDA MD Staff',
#  'Barton Associates',
#  'Delta Locum Tenens',
#  'CompHealth',
#  'Weatherby Healthcare',
#  'LocumTenens.com',
#  'Samuel Contract Staffing',
#  'The Delta Companies',
#  'Annashae Consulting and Staffing',
#  'VISTA Staffing Solutions',
#  'Healthcare Staffing Solutions, Inc',
#  'Physician Providers Mgmt. Corp.',
#  'Tandym Health',
#  'MDM Search',
#  'Ironside Human Resources',
#  'The Medicus Firm',
#  'UPMC',
#  'Vituity',
#  'Ardent Health Services',
#  'Tenet Healthcare',
#  'BayMark Health Services',
#  'CorroHealth',
#  'Inspire Healthcare',
#  'Medicorp, Inc. dba Physician Empire',
#  'Merritt Hawkins',
#  'Medicus Healthcare Solutions',
#  'Goldfish Medical Staffing',
#  'InSync Healthcare Recruiters',
#  'Moonlighting Solutions',
#  'OneOncology',
#  'Delphi Healthcare',
#  'Rural Physicians Group',
#  'Baptist Health Central Alabama',
#  'Privia Medical Group',
# ...

# %%
set(list(final_df["title"]))
# Out:
# {'OB Hospitalist Needed in Oregon',
#  'Enjoy a M-F Schedule and 1:6 Call Near Providence, Rhode Island',
#  'Downtown Nashville Hospitalist Team - No Procedures or Running Codes',
#  'OBGYN needed full time in Memphis Tennessee',
#  'Family Physicians making 350K-400K, Outpatient only',
#  'Outpatient Family Medicine Physician job in scenic North Carolina',
#  'Internal Medicine physician needed in Greensboro, GA, near Lake Oconee and Reynolds Plantation (SA190240)',
#  'Trusted, Cutting-Edge Pittsburgh Dermatology Group - Flexible Hours',
#  'Pediatric PM&R Physician - San Joaquin Valley, California',
#  'Family/Internal Physicians needed in the Medford, OR area (1527)',
#  'Quad Cities, Iowa - OB/GYN - Sign-On Bonus',
#  'OB / GYN',
#  'Board Certified Full-Time Permanent Gastroenterologist needed - Upstate New York',
#  'Adult Psychiatrist needed in Youngstown, OH',
#  'Per Diem Program Physician',
# ...

# %%
final_df.drop_duplicates(inplace =  True)

# %%
final_df
# Out:
#                            _id  \
# 0     648065ab2aef3cb1519b437f
# 1     648065ab2aef3cb1519b4380
# 2     648065ab2aef3cb1519b4381
# 3     648065ab2aef3cb1519b4382
# 4     648065ab2aef3cb1519b4383
# ...                        ...
# 2494  648065ab2aef3cb1519b4dbb
# 2495  648065ab2aef3cb1519b4dbc
# 2496  648065ab2aef3cb1519b4dbd
# 2497  648065ab2aef3cb1519b4dbe
# 2498  648065ab2aef3cb1519b4dbf
#
#                                                   title  location  \
# 0     Internal Medicine Physician needed in Bossier ...       NaN
# 1                  Medical Oncology - Laurium, Michigan       NaN
# 2     Physician (MD/MO) - Pulmonology in Crown Point...       NaN
# 3           Physician (MD/MO) - Urology in Florence, KY       NaN
# 4     Locum Physician (MD/MO) - Anesthesiology in Mi...       NaN
# ...                                                 ...       ...
# 2494          Maternal-Fetal Med position in DuBois, PA       NaN
# ...

# %%
final_df["Upper_of_company"] = final_df["company"].apply(lambda x : x.upper())

# %%
final_df
# Out:
#                            _id  \
# 0     648065ab2aef3cb1519b437f
# 1     648065ab2aef3cb1519b4380
# 2     648065ab2aef3cb1519b4381
# 3     648065ab2aef3cb1519b4382
# 4     648065ab2aef3cb1519b4383
# ...                        ...
# 2494  648065ab2aef3cb1519b4dbb
# 2495  648065ab2aef3cb1519b4dbc
# 2496  648065ab2aef3cb1519b4dbd
# 2497  648065ab2aef3cb1519b4dbe
# 2498  648065ab2aef3cb1519b4dbf
#
#                                                   title  location  \
# 0     Internal Medicine Physician needed in Bossier ...       NaN
# 1                  Medical Oncology - Laurium, Michigan       NaN
# 2     Physician (MD/MO) - Pulmonology in Crown Point...       NaN
# 3           Physician (MD/MO) - Urology in Florence, KY       NaN
# 4     Locum Physician (MD/MO) - Anesthesiology in Mi...       NaN
# ...                                                 ...       ...
# 2494          Maternal-Fetal Med position in DuBois, PA       NaN
# ...

# %%
final_df["Lower_of_Title"] = final_df["title"].apply(lambda i : i.lower())

# %%
final_df
# Out:
#                            _id  \
# 0     648065ab2aef3cb1519b437f
# 1     648065ab2aef3cb1519b4380
# 2     648065ab2aef3cb1519b4381
# 3     648065ab2aef3cb1519b4382
# 4     648065ab2aef3cb1519b4383
# ...                        ...
# 2494  648065ab2aef3cb1519b4dbb
# 2495  648065ab2aef3cb1519b4dbc
# 2496  648065ab2aef3cb1519b4dbd
# 2497  648065ab2aef3cb1519b4dbe
# 2498  648065ab2aef3cb1519b4dbf
#
#                                                   title  location  \
# 0     Internal Medicine Physician needed in Bossier ...       NaN
# 1                  Medical Oncology - Laurium, Michigan       NaN
# 2     Physician (MD/MO) - Pulmonology in Crown Point...       NaN
# 3           Physician (MD/MO) - Urology in Florence, KY       NaN
# 4     Locum Physician (MD/MO) - Anesthesiology in Mi...       NaN
# ...                                                 ...       ...
# 2494          Maternal-Fetal Med position in DuBois, PA       NaN
# ...

# %%
def upper_title(x): 
    a = x.upper()
    return a

# %%
final_df["Upper_of_Title"] = final_df["title"].apply(lambda i : upper_title(i))

# %%
final_df
# Out:
#                            _id  \
# 0     648065ab2aef3cb1519b437f
# 1     648065ab2aef3cb1519b4380
# 2     648065ab2aef3cb1519b4381
# 3     648065ab2aef3cb1519b4382
# 4     648065ab2aef3cb1519b4383
# ...                        ...
# 2494  648065ab2aef3cb1519b4dbb
# 2495  648065ab2aef3cb1519b4dbc
# 2496  648065ab2aef3cb1519b4dbd
# 2497  648065ab2aef3cb1519b4dbe
# 2498  648065ab2aef3cb1519b4dbf
#
#                                                   title  location  \
# 0     Internal Medicine Physician needed in Bossier ...       NaN
# 1                  Medical Oncology - Laurium, Michigan       NaN
# 2     Physician (MD/MO) - Pulmonology in Crown Point...       NaN
# 3           Physician (MD/MO) - Urology in Florence, KY       NaN
# 4     Locum Physician (MD/MO) - Anesthesiology in Mi...       NaN
# ...                                                 ...       ...
# 2494          Maternal-Fetal Med position in DuBois, PA       NaN
# ...

# %%
def lower_company(x):
    a = x.lower()
    return a

# %%
final_df["Lower_of_company"] = final_df["company"].apply(lambda i : lower_company(i))

# %%
final_df
# Out:
#                            _id  \
# 0     648065ab2aef3cb1519b437f
# 1     648065ab2aef3cb1519b4380
# 2     648065ab2aef3cb1519b4381
# 3     648065ab2aef3cb1519b4382
# 4     648065ab2aef3cb1519b4383
# ...                        ...
# 2494  648065ab2aef3cb1519b4dbb
# 2495  648065ab2aef3cb1519b4dbc
# 2496  648065ab2aef3cb1519b4dbd
# 2497  648065ab2aef3cb1519b4dbe
# 2498  648065ab2aef3cb1519b4dbf
#
#                                                   title  location  \
# 0     Internal Medicine Physician needed in Bossier ...       NaN
# 1                  Medical Oncology - Laurium, Michigan       NaN
# 2     Physician (MD/MO) - Pulmonology in Crown Point...       NaN
# 3           Physician (MD/MO) - Urology in Florence, KY       NaN
# 4     Locum Physician (MD/MO) - Anesthesiology in Mi...       NaN
# ...                                                 ...       ...
# 2494          Maternal-Fetal Med position in DuBois, PA       NaN
# ...

# %%
def split_id(x):
    i = x.split('a')
    return i

# %%
final_df["split_of_id"] = final_df["_id"].apply(lambda i : split_id(i))

# %%
final_df
# Out:
#                            _id  \
# 0     648065ab2aef3cb1519b437f
# 1     648065ab2aef3cb1519b4380
# 2     648065ab2aef3cb1519b4381
# 3     648065ab2aef3cb1519b4382
# 4     648065ab2aef3cb1519b4383
# ...                        ...
# 2494  648065ab2aef3cb1519b4dbb
# 2495  648065ab2aef3cb1519b4dbc
# 2496  648065ab2aef3cb1519b4dbd
# 2497  648065ab2aef3cb1519b4dbe
# 2498  648065ab2aef3cb1519b4dbf
#
#                                                   title  location  \
# 0     Internal Medicine Physician needed in Bossier ...       NaN
# 1                  Medical Oncology - Laurium, Michigan       NaN
# 2     Physician (MD/MO) - Pulmonology in Crown Point...       NaN
# 3           Physician (MD/MO) - Urology in Florence, KY       NaN
# 4     Locum Physician (MD/MO) - Anesthesiology in Mi...       NaN
# ...                                                 ...       ...
# 2494          Maternal-Fetal Med position in DuBois, PA       NaN
# ...

# %%
final_df["split_of_company"] = final_df["company"].apply(lambda i : i.split('t'))

# %%
final_df
# Out:
#                            _id  \
# 0     648065ab2aef3cb1519b437f
# 1     648065ab2aef3cb1519b4380
# 2     648065ab2aef3cb1519b4381
# 3     648065ab2aef3cb1519b4382
# 4     648065ab2aef3cb1519b4383
# ...                        ...
# 2494  648065ab2aef3cb1519b4dbb
# 2495  648065ab2aef3cb1519b4dbc
# 2496  648065ab2aef3cb1519b4dbd
# 2497  648065ab2aef3cb1519b4dbe
# 2498  648065ab2aef3cb1519b4dbf
#
#                                                   title  location  \
# 0     Internal Medicine Physician needed in Bossier ...       NaN
# 1                  Medical Oncology - Laurium, Michigan       NaN
# 2     Physician (MD/MO) - Pulmonology in Crown Point...       NaN
# 3           Physician (MD/MO) - Urology in Florence, KY       NaN
# 4     Locum Physician (MD/MO) - Anesthesiology in Mi...       NaN
# ...                                                 ...       ...
# 2494          Maternal-Fetal Med position in DuBois, PA       NaN
# ...

# %%
def split_title(x,y):
    p = x.split('i')
    return p,y

# %%
y = 'a'
final_df["split_of_title"] = final_df["title"].apply(lambda x : split_title(x,y))

# %%
final_df
# Out:
#                            _id  \
# 0     648065ab2aef3cb1519b437f
# 1     648065ab2aef3cb1519b4380
# 2     648065ab2aef3cb1519b4381
# 3     648065ab2aef3cb1519b4382
# 4     648065ab2aef3cb1519b4383
# ...                        ...
# 2494  648065ab2aef3cb1519b4dbb
# 2495  648065ab2aef3cb1519b4dbc
# 2496  648065ab2aef3cb1519b4dbd
# 2497  648065ab2aef3cb1519b4dbe
# 2498  648065ab2aef3cb1519b4dbf
#
#                                                   title  location  \
# 0     Internal Medicine Physician needed in Bossier ...       NaN
# 1                  Medical Oncology - Laurium, Michigan       NaN
# 2     Physician (MD/MO) - Pulmonology in Crown Point...       NaN
# 3           Physician (MD/MO) - Urology in Florence, KY       NaN
# 4     Locum Physician (MD/MO) - Anesthesiology in Mi...       NaN
# ...                                                 ...       ...
# 2494          Maternal-Fetal Med position in DuBois, PA       NaN
# ...

# %%
df_2
# Out:
#                            _id  \
# 0     648065ab2aef3cb1519b437f
# 1     648065ab2aef3cb1519b4380
# 2     648065ab2aef3cb1519b4381
# 3     648065ab2aef3cb1519b4382
# 4     648065ab2aef3cb1519b4383
# ...                        ...
# 1994  648065ab2aef3cb1519b4bb9
# 1995  648065ab2aef3cb1519b4bba
# 1996  648065ab2aef3cb1519b4bbb
# 1997  648065ab2aef3cb1519b4bbc
# 1998  648065ab2aef3cb1519b4bbd
#
#                                                   title  location  \
# 0     Internal Medicine Physician needed in Bossier ...       NaN
# 1                  Medical Oncology - Laurium, Michigan       NaN
# 2     Physician (MD/MO) - Pulmonology in Crown Point...       NaN
# 3           Physician (MD/MO) - Urology in Florence, KY       NaN
# 4     Locum Physician (MD/MO) - Anesthesiology in Mi...       NaN
# ...                                                 ...       ...
# 1994  New York Opportunity Partnered with Massachuse...       NaN
# ...

# %%
df_3
# Out:
#                            _id  \
# 0     648065ab2aef3cb1519b437f
# 1     648065ab2aef3cb1519b4380
# 2     648065ab2aef3cb1519b4381
# 3     648065ab2aef3cb1519b4382
# 4     648065ab2aef3cb1519b4383
# ...                        ...
# 2494  648065ab2aef3cb1519b4dbb
# 2495  648065ab2aef3cb1519b4dbc
# 2496  648065ab2aef3cb1519b4dbd
# 2497  648065ab2aef3cb1519b4dbe
# 2498  648065ab2aef3cb1519b4dbf
#
#                                                   title  location  \
# 0     Internal Medicine Physician needed in Bossier ...       NaN
# 1                  Medical Oncology - Laurium, Michigan       NaN
# 2     Physician (MD/MO) - Pulmonology in Crown Point...       NaN
# 3           Physician (MD/MO) - Urology in Florence, KY       NaN
# 4     Locum Physician (MD/MO) - Anesthesiology in Mi...       NaN
# ...                                                 ...       ...
# 2494          Maternal-Fetal Med position in DuBois, PA       NaN
# ...

# %%
df = df_2.merge(df_3 , on = 'company', axis = 1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 df = df_2.merge(df_3 , on = 'company', axis = 1)
#
# TypeError: DataFrame.merge() got an unexpected keyword argument 'axis'

# %%
df
# Out:
#                            _id_x  \
# 0       648065ab2aef3cb1519b437f
# 1       648065ab2aef3cb1519b4380
# 2       648065ab2aef3cb1519b4381
# 3       648065ab2aef3cb1519b4381
# 4       648065ab2aef3cb1519b4381
# ...                          ...
# 253072  648065ab2aef3cb1519b4bb5
# 253073  648065ab2aef3cb1519b4bb5
# 253074  648065ab2aef3cb1519b4bb5
# 253075  648065ab2aef3cb1519b4bb5
# 253076  648065ab2aef3cb1519b4bb5
#
#                                                   title_x  location_x  \
# 0       Internal Medicine Physician needed in Bossier ...         NaN
# 1                    Medical Oncology - Laurium, Michigan         NaN
# 2       Physician (MD/MO) - Pulmonology in Crown Point...         NaN
# 3       Physician (MD/MO) - Pulmonology in Crown Point...         NaN
# 4       Physician (MD/MO) - Pulmonology in Crown Point...         NaN
# ...                                                   ...         ...
# ...
